# %% [markdown]
# `ToAdd` and `ValueError`

# %%
def ToAdd(n,p):
    """put your code below"""
    ### BEGIN SOLUTION
    if p < 1:
        raise ValueError("p must be greater than or equal to 1")
    return(n+p)
    ### END SOLUTION
ToAdd(56,44)
# Out:
# 100

# %% [markdown]
# Find answer to make output = 100

# %% [markdown]
# `ToSubtract` and `ValueError`

# %%
def ToSubtract(n,p):
    """put your code below"""
    ### BEGIN SOLUTION
    if p < 1:
        raise ValueError("p must be greater than or equal to 1")
    return(n-p)
    ### END SOLUTION
ToSubtract(99,55)
# Out:
# 44

# %%
Find answer to make output = 44

# %% [markdown]
# `ToMultiply` and `ValueError`

# %%
def ToMultiply(n,p):
    """put your code below"""
    ### BEGIN SOLUTION
    if p < 1:
        raise ValueError("p must be greater than or equal to 1")
    return(n*p)
    ### END SOLUTION
ToMultiply(75,63)
# Out:
# 4725

# %%
Find answer to make output = 4725

# %% [markdown]
# `ToDivide` and `ValueError`

# %%
def ToDivide(n,p):
    """put your code below"""
    ### BEGIN SOLUTION
    if p < 1:
        raise ValueError("p must be greater than or equal to 1")
    return(n/p)
    ### END SOLUTION
ToDivide(1200,25)
# Out:
# 48.0

# %%
Find answer to make output = 48

# %%
assert ToDivide(200,5) == 40

# %%
assert ToAdd(ToDivide(ToSubtract(9,6),ToSubtract(125,29)),ToMultiply(ToSubtract(89,56),ToSubtract(25,19))) == 198.03125
